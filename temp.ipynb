# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from configparser import ConfigParser
import os
from utils import download_songs
import librosa

configur = ConfigParser()
configur.read("config.ini")
client_id = configur["main"]["client_id"]
client_secret = configur["main"]["client_secret"]
client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id, client_secret=client_secret
)
sp = spotipy.Spotify(
    client_credentials_manager=client_credentials_manager
)  # sp is the instance of the spotipy api

# %%
data = pd.read_csv('big5_mft_tracks.csv')
preview_url = data['preview_url']
track_id = data['track_id']
data
# Out:
#        Unnamed: 0        artist_name            song_title  \
# 0               5        12th Planet                Follow
# 1               6        12th Planet  Swamplex Terrestrial
# 2               7        12th Planet             Supernova
# 3               8        12th Planet           Let It Bang
# 4               9        12th Planet           Let Us Prey
# ...           ...                ...                   ...
# 11175       14140  Twenty One Pilots          Stressed Out
# 11176       14141  Twenty One Pilots                  Ride
# 11177       14142  Twenty One Pilots              Heathens
# 11178       14143  Twenty One Pilots              Chlorine
# 11179       14144  Twenty One Pilots      Tear in My Heart
#
#                                              preview_url  \
# 0      https://p.scdn.co/mp3-preview/ef07dc598b117870...
# 1      https://p.scdn.co/mp3-preview/bfe1fffd48350137...
# 2      https://p.scdn.co/mp3-preview/a492095a74937ed7...
# ...

# %%
# download_songs(preview_url, track_id)
# print('Dataset Downloaded ....')

# %%
a = [43050,5000,14000,33600,86850,5000,200000,150000,248000,14000,50000,1000000,4500,10000,10000,10000,6500,150000,30000,
21600,55748,18193,20049,1000000,800000,250000,6000,50000,17700]
print(sum(a))
b = [8000,6200,12000,5000,5000,1567000,3000,25000,25000,6000,10000,33000,33000,4000,25000,100000,52800,2332,75000,37400]
print(sum(b))
c = [21600,55748,18193.50,20049]
print(sum(c))
print('Total :-', sum(a)+sum(b))
print('Total - card', (sum(a)+sum(b)-sum(c)) )
# Out:
# 4309790
# 2034732
# 115590.5
# Total :- 6344522
# Total - card 6228931.5

# %%
# # for i in 
# aro = audioread.ffdec.FFmpegAudioFile(librosa.ex('brahms'))
# y, sr = librosa.load(aro)

# # load all files and extract rythm features (high level features from librosa)

# %%
import librosa
import soundfile  # Use ffmpeg decoder
loc = '/Users/yash/Downloads/downloaded_songs'
feature_list = []
for root, dirs, files in os.walk(loc):
    for f in files:
        if os.path.splitext(f)[1] != '.mp3':
            continue
        track = f.split('.')[0]
        file_path = os.path.join(root, f)
        y, sr = librosa.load(file_path, sr=22050)

        hop_length = 512
        oenv = librosa.onset.onset_strength(y=y, sr=sr, hop_length=hop_length)
        tempogram = librosa.feature.tempogram(onset_envelope=oenv, sr=sr,
                                            hop_length=hop_length)
        # Compute global onset autocorrelation
        ac_global = librosa.autocorrelate(oenv, max_size=tempogram.shape[0])
        ac_global = librosa.util.normalize(ac_global)
        # Estimate the global tempo for display purposes
        tempo = librosa.beat.tempo(onset_envelope=oenv, sr=sr,
                                hop_length=hop_length)[0]
        feature_list.append([track,tempo])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
# ...

# %%
df_featrues = pd.DataFrame(file_path_list)
df_featrues
# Out:
#                                                    0           1
# 0  /Users/yash/Downloads/downloaded_songs/0/0D/0d...  161.499023
# 1  /Users/yash/Downloads/downloaded_songs/0/0D/0D...  151.999081
# 2  /Users/yash/Downloads/downloaded_songs/0/0D/0D...  117.453835
# 3  /Users/yash/Downloads/downloaded_songs/0/0D/0d...  151.999081
# 4  /Users/yash/Downloads/downloaded_songs/0/0D/0d...  143.554688
# 5  /Users/yash/Downloads/downloaded_songs/0/0D/0D...  123.046875
# 6  /Users/yash/Downloads/downloaded_songs/0/0D/0D...   95.703125
# 7  /Users/yash/Downloads/downloaded_songs/0/0D/0d...  103.359375

# %%
# Out:
# '0d7ZSzBzMW5QLIQiuRm83a'
